# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieldorte/carteira_investimentos/blob/main/analise_carteira_investimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalando bibliotecas
# !pip install fundamentus yfinance
# Out:
# Collecting fundamentus
#   Downloading fundamentus-0.2.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.54)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.11/dist-packages (from fundamentus) (2.32.3)
# Collecting requests-cache>=0.5.2 (from fundamentus)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from fundamentus) (2.2.2)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.11/dist-packages (from fundamentus) (5.3.1)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.11/dist-packages (from fundamentus) (0.9.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->fundamentus) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->fundamentus) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->fundamentus) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->fundamentus) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->fundamentus) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->fundamentus) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=0.5.2->fundamentus) (25.1.0)
# Collecting cattrs>=22.2 (from requests-cache>=0.5.2->fundamentus)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting url-normalize>=1.4 (from requests-cache>=0.5.2->fundamentus)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->fundamentus) (1.17.0)
# Downloading fundamentus-0.2.0-py3-none-any.whl (13 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.6 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.3 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, fundamentus
# Successfully installed cattrs-24.1.2 fundamentus-0.2.0 requests-cache-1.2.1 url-normalize-1.4.3

# %%
# Importando a biblioteca
import yfinance as yf

# %%
# Definindo a carteira de ações
carteira_yf = ['ABEV3.SA', 'B3SA3.SA', 'ELET3.SA', 'GGBR4.SA', 'ITSA4.SA',
               'PETR4.SA', 'RENT3.SA', 'SUZB3.SA', 'VALE3.SA', 'WEGE3.SA']

# %%
# Carregando os dados da carteira
df = yf.download(carteira_yf, start='2022-08-01', end = '2023-08-01')
df.head(3)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed
# Price           Close                                                        \
# Ticker       ABEV3.SA   B3SA3.SA   ELET3.SA   GGBR4.SA  ITSA4.SA   PETR4.SA
# Date
# 2022-08-01  12.954397   9.965703  44.577351  15.262520  5.548090  16.199020
# 2022-08-02  13.025235   9.901527  44.922466  15.733232  5.600060  16.271166
# 2022-08-03  12.954397  10.231577  45.066257  15.094872  5.645537  16.280785
#
# Price                                                   ...    Volume  \
# Ticker       RENT3.SA   SUZB3.SA   VALE3.SA   WEGE3.SA  ...  ABEV3.SA
# Date                                                    ...
# 2022-08-01  52.656380  43.352535  55.528900  26.874165  ...  34565900
# 2022-08-02  52.905109  43.708706  57.298851  27.356129  ...  12515800
# 2022-08-03  54.554073  43.224674  55.072147  27.105505  ...  19576600
#
# Price                                                                  \
# Ticker      B3SA3.SA  ELET3.SA  GGBR4.SA  ITSA4.SA  PETR4.SA RENT3.SA
# Date
# 2022-08-01  26237600  12239200  16655058  25799552  81365100  6769429
# 2022-08-02  29130100   7477600  16078734  15750344  69147100  4870629
# 2022-08-03  29172900   8281500  30645468  25337732  65544500  4927295
#
# Price
# Ticker     SUZB3.SA  VALE3.SA WEGE3.SA
# Date
# 2022-08-01  7127600  38874000  8202200
# 2022-08-02  4379000  32636900  7214800
# 2022-08-03  4451900  31934600  6627100
#
# [3 rows x 50 columns]

# %%
# Passando os ativos para o multindex do df
cotacoes = df.stack(level = 1)
cotacoes
# Out:
# <ipython-input-5-06661b001fab>:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cotacoes = df.stack(level = 1)
# Price                    Close       High        Low       Open    Volume
# Date       Ticker
# 2022-08-01 ABEV3.SA  12.954397  13.184619  12.777304  13.158054  34565900
#            B3SA3.SA   9.965703  10.194905   9.819014  10.103225  26237600
#            ELET3.SA  44.577351  44.951225  43.772082  43.906293  12239200
#            GGBR4.SA  15.262520  15.881533  15.152904  15.881533  16655058
#            ITSA4.SA   5.548090   5.639042   5.489620   5.619552  25799552
# ...                        ...        ...        ...        ...       ...
# 2023-07-31 PETR4.SA  23.544428  23.574700  22.931409  22.931409  91290800
#            RENT3.SA  63.632687  64.049205  62.894317  63.462296   5980447
#            SUZB3.SA  45.487907  45.998902  44.797120  44.844433   4602700
#            VALE3.SA  60.842949  61.300412  59.681683  59.822445  26065700
#            WEGE3.SA  39.072895  39.435046  38.965232  39.435046   7141800
#
# [2500 rows x 5 columns]

# %%
cotacoes = cotacoes = cotacoes.reset_index().rename(columns={"Ticker": "Ativo"})
cotacoes = cotacoes[["Date", "Open", "High", "Low", "Close", "Ativo"]]
cotacoes.head(10)
# Out:
# Price       Date       Open       High        Low      Close     Ativo
# 0     2022-08-01  13.158054  13.184619  12.777304  12.954397  ABEV3.SA
# 1     2022-08-01  10.103225  10.194905   9.819014   9.965703  B3SA3.SA
# 2     2022-08-01  43.906293  44.951225  43.772082  44.577351  ELET3.SA
# 3     2022-08-01  15.881533  15.881533  15.152904  15.262520  GGBR4.SA
# 4     2022-08-01   5.619552   5.639042   5.489620   5.548090  ITSA4.SA
# 5     2022-08-01  16.352930  16.425076  15.977775  16.199020  PETR4.SA
# 6     2022-08-01  52.877468  53.319651  52.324742  52.656380  RENT3.SA
# 7     2022-08-01  44.165338  44.165338  42.877639  43.352535  SUZB3.SA
# 8     2022-08-01  56.230353  56.972584  55.406553  55.528900  VALE3.SA
# 9     2022-08-01  27.028394  27.645304  26.768134  26.874165  WEGE3.SA

# %%
cotacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2500 non-null   datetime64[ns]
#  1   Open    2500 non-null   float64
#  2   High    2500 non-null   float64
#  3   Low     2500 non-null   float64
#  4   Close   2500 non-null   float64
#  5   Ativo   2500 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 117.3+ KB
